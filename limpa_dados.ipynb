# %% [markdown]
# # Limpa Dados Notebook

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

# %%
df = pd.read_csv('./SINAN_Br.csv', sep=',', low_memory=False, index_col=1)
df.head()
# Out:
#            TP_NOT  NU_ANO UF_NOT REGIAO_NOT  COD_MUN     DT_OCOR dia_ocor  anosid    sexo tempo_gestacao gestante    raca                       educacao  ID_OCUPA_N  estcivil     orient_sex id_gen def_trans def_fisica def_mental def_visual def_auditi tran_ment tran_comp def_outras UF_OCOR REGIAO_OCOR ZONA_OCOR  HORA_OCOR HORA_Cat   LOCAL_OCOR OUT_VEZES LES_AUTOP VIOL_MOTIV VIOL_FISIC VIOL_PSICO VIOL_TORT VIOL_SEXU VIOL_TRAF VIOL_FINAN VIOL_NEGLI VIOL_INFAN VIOL_LEGAL VIOL_OUTR AG_FORCA AG_ENFOR AG_OBJETO AG_CORTE AG_QUENTE AG_ENVEN AG_FOGO AG_AMEACA AG_OUTROS SEX_ASSEDI SEX_ESTUPR SEX_PORNO SEX_EXPLO SEX_OUTRO PROC_DST PROC_HIV PROC_HEPB PROC_SANG PROC_SEMEN PROC_VAGIN PROC_CONTR PROC_ABORT    NUM_ENVOLV REL_PAI REL_MAE REL_PAD REL_MAD REL_CONJ REL_EXCON REL_NAMO REL_EXNAM REL_FILHO REL_IRMAO REL_CONHEC REL_DESCO REL_CUIDA REL_PATRAO REL_INST REL_POL REL_PROPRI REL_OUTROS AUTOR_SEXO AUTOR_ALCO       CICL_VID  ENC_SAUDE ASSIST_SOC REDE_EDUCA ATEND_MULH CONS_TUTEL CONS_IDO DELEG_IDOS D
# ...

# %%
df.drop(columns=[
    'UF_NOT',
    'REGIAO_NOT',
    'COD_MUN',
    'DT_OCOR',
    'tempo_gestacao',
    'gestante',
    'educacao',
    'ID_OCUPA_N',
    'ZONA_OCOR',
    'HORA_OCOR',
    'HORA_Cat',
    'OUT_VEZES',
    'NUM_ENVOLV',
    'PROC_ABORT',
    'PROC_VAGIN',
    'PROC_CONTR',
    'PROC_SEMEN',
    'PROC_SANG',
    'PROC_HEPB',
    'PROC_HIV',
    'PROC_DST',
    'SEX_OUTRO',
    'AUTOR_SEXO',
    'AUTOR_ALCO',
    'CICL_VID',
    'ENC_SAUDE',
    'ASSIST_SOC',
    'REDE_EDUCA',
    'ATEND_MULH',
    'CONS_TUTEL',
    'CONS_IDO',
    'DELEG_IDOS',
    'DIR_HUMAN',
    'MPU',
    'DELEG_CRIA',
    'DELEG_MULH',
    'DELEG',
    'INFAN_JUV',
    'DEFEN_PUBL',
    'ID_GEO3',
    'ID_GEO4',
    'TP_NOT',
    'dia_ocor',
], axis=1, inplace=True)

# %%
df.rename({
    'NU_ANO': 'ano_da_ocorrencia',
    'anosid': 'anos_idade',
    'sexo': 'sexo',
    'raca': 'raca',
    'estcivil': 'estado_civil',
    'orient_sex': 'orientacao_sexual',
    'id_gen': 'identidade_de_genero',
    'def_trans': 'Possui deficiencia ou transtorno',
    'def_fisica': 'Deficiencia fisica',
    'def_mental': 'Deficiencia mental',
    'def_visual': 'Deficiencia visual',
    'def_auditi': 'Deficiencia auditiva',
    'tran_ment': 'Transtorno mental',
    'tran_comp': 'Transtorno comportamental',
    'def_outras': 'Outras deficiencias ou transtornos',
    'UF_OCOR': 'estado_da_ocorrencia',
    'REGIAO_OCOR': 'regiao_da_ocorrencia',
    'LOCAL_OCOR': 'local_da_ocorrencia',
    'LES_AUTOP': 'Lesão auto-provocada',
    'VIOL_MOTIV': 'Motivo da violencia',
    'VIOL_FISIC': 'Violencia fisica',
    'VIOL_PSICO': 'Violencia psicológica',
    'VIOL_TORT': 'Tortura',
    'VIOL_SEXU': 'Violencia sexual',
    'VIOL_TRAF': 'Trafico de seres humanos',
    'VIOL_FINAN': 'Violencia financeira ou economica',
    'VIOL_NEGLI': 'Negligencia ou abandono',
    'VIOL_INFAN': 'Violencia infantil',
    'VIOL_LEGAL': 'Violencia cometida por agente da lei',
    'VIOL_OUTR': 'Outros tipos de violência',
    'AG_FORCA': 'Forca corporal ou espancamento',
    'AG_ENFOR': 'Enforcamento',
    'AG_OBJETO': 'Objeto contundente',
    'AG_CORTE': 'Perfuro cortante',
    'AG_QUENTE': 'Substancia ou objeto quente',
    'AG_ENVEN': 'Envenenamento',
    'AG_FOGO': 'Arma de fogo',
    'AG_AMEACA': 'Ameaca',
    'AG_OUTROS': 'Outros tipos de agressao',
    'SEX_ASSEDI': 'Assedio sexual',
    'SEX_ESTUPR': 'Estupro',
    'SEX_PORNO': 'Pornografia infantil',
    'SEX_EXPLO': 'Exploracao sexual',
    'REL_PAI': 'Pai',
    'REL_MAE': 'Mãe',
    'REL_PAD': 'Padrasto',
    'REL_MAD': 'Madrasta',
    'REL_CONJ': 'Conjugue',
    'REL_EXCON': 'Ex-Conjunge',
    'REL_NAMO': 'Namorado(a)',
    'REL_EXNAM': 'Ex-Namorado(a)',
    'REL_FILHO': 'Filho(a)',
    'REL_IRMAO': 'Irmao(a)',
    'REL_CONHEC': 'Conhecido(a)',
    'REL_DESCO': 'Desconhecido(a)',
    'REL_CUIDA': 'Cuidador(a)',
    'REL_PATRAO': 'Patrao(a)/Chefe(a)',
    'REL_INST': 'Relacao institucional',
    'REL_POL': 'Policial ou agente da lei',
    'REL_PROPRI': 'Propria pessoa',
    'REL_OUTROS': 'Outro tipo de relacao',
    'MUNICIPIO': 'municipio_da_ocorrencia',
    'x': 'longitude',
    'y': 'latitude',
}, axis=1, inplace=True)



# meio_de_agressao
# tipo_de_agressao
# vinculo_com_vitima,
# base_dados

# %%
df.head()
# Out:
#            ano_da_ocorrencia  anos_idade    sexo    raca estado_civil orientacao_sexual identidade_de_genero Possui deficiencia ou transtorno Deficiencia fisica Deficiencia mental Deficiencia visual Deficiencia auditiva Transtorno mental Transtorno comportamental Outras deficiencias ou transtornos estado_da_ocorrencia regiao_da_ocorrencia local_da_ocorrencia Lesão auto-provocada Motivo da violencia Violencia fisica Violencia psicológica Tortura Violencia sexual Trafico de seres humanos Violencia financeira ou economica Negligencia ou abandono Violencia infantil Violencia cometida por agente da lei Outros tipos de violência Forca corporal ou espancamento Enforcamento Objeto contundente Perfuro cortante Substancia ou objeto quente Envenenamento Arma de fogo Ameaca Outros tipos de agressao Assedio sexual Estupro Pornografia infantil Exploracao sexual  Pai  Mãe Padrasto Madrasta Conjugue Ex-Conjunge Namorado(a) Ex-Namorado(a) Filho(a) Irmao(a) Conhecido(a) Desconhecido(a) Cuidador(a) Pat
# ...

# %%
df[list(df.filter(like='ano_da_ocorrencia'))] = df[list(df.filter(like='ano_da_ocorrencia'))].fillna(0)
df[list(df.filter(like='anos_idade'))] = df[list(df.filter(like='anos_idade'))].fillna(0)
df[list(df.filter(like='sexo'))] = df[list(df.filter(like='sexo'))].fillna('Sem dados')
df[list(df.filter(like='raca'))] = df[list(df.filter(like='raca'))].fillna('Sem dados')
df[list(df.filter(like='estado_civil'))] = df[list(df.filter(like='estado_civil'))].fillna('Sem dados')
df[list(df.filter(like='orientacao_sexual'))] = df[list(df.filter(like='orientacao_sexual'))].fillna('Sem dados')
df[list(df.filter(like='identidade_de_genero'))] = df[list(df.filter(like='identidade_de_genero'))].fillna('Sem dados')

df[list(df.filter(like='Possui deficiencia ou transtorno'))] = df[list(df.filter(like='Possui deficiencia ou transtorno'))].fillna('Sem dados')
df[list(df.filter(like='Deficiencia'))] = df[list(df.filter(like='Deficiencia'))].fillna('Sem dados')
df[list(df.filter(like='Transtorno'))] = df[list(df.filter(like='Transtorno'))].fillna('Sem dados')
df[list(df.filter(like='Outras deficiencias ou transtornos'))] = df[list(df.filter(like='Outras deficiencias ou transtornos'))].fillna('Sem dados')

df[list(df.filter(like='estado_da_ocorrencia'))] = df[list(df.filter(like='estado_da_ocorrencia'))].fillna('Sem dados')
df[list(df.filter(like='regiao_da_ocorrencia'))] = df[list(df.filter(like='regiao_da_ocorrencia'))].fillna('Sem dados')
df[list(df.filter(like='local_da_ocorrencia'))] = df[list(df.filter(like='local_da_ocorrencia'))].fillna('Sem dados')
df[list(df.filter(like='Lesão auto-provocada'))] = df[list(df.filter(like='Lesão auto-provocada'))].fillna('Sem dados')
df[list(df.filter(like='Motivo da violencia'))] = df[list(df.filter(like='Motivo da violencia'))].fillna('Sem dados')
df[list(df.filter(like='Violencia'))] = df[list(df.filter(like='Violencia'))].fillna('Sem dados')
df[list(df.filter(like='Tortura'))] = df[list(df.filter(like='Tortura'))].fillna('Sem dados')
df[list(df.filter(like='Trafico de seres humanos'))] = df[list(df.filter(like='Trafico de seres humanos'))].fillna('Sem dados')
df[list(df.filter(like='Negligencia ou abandono'))] = df[list(df.filter(like='Negligencia ou abandono'))].fillna('Sem dados')
df[list(df.filter(like='Outros'))] = df[list(df.filter(like='Outros'))].fillna('Sem dados')
df[list(df.filter(like='Forca corporal ou espancamento'))] = df[list(df.filter(like='Forca corporal ou espancamento'))].fillna('Sem dados')
df[list(df.filter(like='Objeto contundente'))] = df[list(df.filter(like='Objeto contundente'))].fillna('Sem dados')
df[list(df.filter(like='Perfuro cortante'))] = df[list(df.filter(like='Perfuro cortante'))].fillna('Sem dados')
df[list(df.filter(like='Substancia ou objeto quente'))] = df[list(df.filter(like='Substancia ou objeto quente'))].fillna('Sem dados')
df[list(df.filter(like='Envenenamento'))] = df[list(df.filter(like='Envenenamento'))].fillna('Sem dados')
df[list(df.filter(like='Arma de fogo'))] = df[list(df.filter(like='Arma de fogo'))].fillna('Sem dados')
df[list(df.filter(like='Ameaca'))] = df[list(df.filter(like='Ameaca'))].fillna('Sem dados')
df[list(df.filter(like='Assedio sexual'))] = df[list(df.filter(like='Assedio sexual'))].fillna('Sem dados')
df[list(df.filter(like='Estupro'))] = df[list(df.filter(like='Estupro'))].fillna('Sem dados')
df[list(df.filter(like='Pornografia infantil'))] = df[list(df.filter(like='Pornografia infantil'))].fillna('Sem dados')
df[list(df.filter(like='Exploracao sexual'))] = df[list(df.filter(like='Exploracao sexual'))].fillna('Sem dados')
df[list(df.filter(like='municipio_da_ocorrencia'))] = df[list(df.filter(like='municipio_da_ocorrencia'))].fillna('Sem dados')
df[list(df.filter(like='latitude'))] = df[list(df.filter(like='latitude'))].fillna(0)
df[list(df.filter(like='longitude'))] = df[list(df.filter(like='longitude'))].fillna(0)


df[list(df.filter(like='Pai'))] = df[list(df.filter(like='Pai'))].fillna('Sem dados')
df[list(df.filter(like='Mãe'))] = df[list(df.filter(like='Mãe'))].fillna('Sem dados')
df[list(df.filter(like='Padrasto'))] = df[list(df.filter(like='Padrasto'))].fillna('Sem dados')
df[list(df.filter(like='Madrasta'))] = df[list(df.filter(like='Madrasta'))].fillna('Sem dados')
df[list(df.filter(like='Conjugue'))] = df[list(df.filter(like='Conjugue'))].fillna('Sem dados')
df[list(df.filter(like='Ex-Conjunge'))] = df[list(df.filter(like='Ex-Conjunge'))].fillna('Sem dados')
df[list(df.filter(like='Namorado(a)'))] = df[list(df.filter(like='Namorado(a)'))].fillna('Sem dados')
df[list(df.filter(like='Ex-Namorado(a)'))] = df[list(df.filter(like='Ex-Namorado(a)'))].fillna('Sem dados')
df[list(df.filter(like='Filho(a)'))] = df[list(df.filter(like='Filho(a)'))].fillna('Sem dados')
df[list(df.filter(like='Irmao(a)'))] = df[list(df.filter(like='Irmao(a)'))].fillna('Sem dados')
df[list(df.filter(like='Conhecido(a)'))] = df[list(df.filter(like='Conhecido(a)'))].fillna('Sem dados')
df[list(df.filter(like='Desconhecido(a)'))] = df[list(df.filter(like='Desconhecido(a)'))].fillna('Sem dados')
df[list(df.filter(like='Cuidador(a)'))] = df[list(df.filter(like='Cuidador(a)'))].fillna('Sem dados')
df[list(df.filter(like='Patrao(a)/Chefe(a)'))] = df[list(df.filter(like='Patrao(a)/Chefe(a)'))].fillna('Sem dados')
df[list(df.filter(like='Relacao institucional'))] = df[list(df.filter(like='Relacao institucional'))].fillna('Sem dados')
df[list(df.filter(like='Policial ou agente da lei'))] = df[list(df.filter(like='Policial ou agente da lei'))].fillna('Sem dados')
df[list(df.filter(like='Propria pessoa'))] = df[list(df.filter(like='Propria pessoa'))].fillna('Sem dados')
df[list(df.filter(like='Outro tipo de relacao'))] = df[list(df.filter(like='Outro tipo de relacao'))].fillna('Sem dados')

# %%
df.head()
# Out:
#            ano_da_ocorrencia  anos_idade    sexo    raca estado_civil orientacao_sexual identidade_de_genero Possui deficiencia ou transtorno Deficiencia fisica Deficiencia mental Deficiencia visual Deficiencia auditiva Transtorno mental Transtorno comportamental Outras deficiencias ou transtornos estado_da_ocorrencia regiao_da_ocorrencia local_da_ocorrencia Lesão auto-provocada Motivo da violencia Violencia fisica Violencia psicológica Tortura Violencia sexual Trafico de seres humanos Violencia financeira ou economica Negligencia ou abandono Violencia infantil Violencia cometida por agente da lei Outros tipos de violência Forca corporal ou espancamento Enforcamento Objeto contundente Perfuro cortante Substancia ou objeto quente Envenenamento Arma de fogo Ameaca Outros tipos de agressao Assedio sexual    Estupro Pornografia infantil Exploracao sexual        Pai        Mãe   Padrasto   Madrasta   Conjugue Ex-Conjunge Namorado(a) Ex-Namorado(a)   Filho(a)   Irmao(a) Conhecido(a) Descon
# ...

# %%
df['vinculo_com_vitima'] = ""

for c in list(df.filter(like='Pai')):
  df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Mãe')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Padrasto')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Madrasta')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Conjugue')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Ex-Conjunge')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Namorado(a)')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Ex-Namorado(a)')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Filho(a)')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Irmao(a)')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Conhecido(a)')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Desconhecido(a)')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Cuidador(a)')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Patrao(a)/Chefe(a)')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Relacao institucional')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Policial ou agente da lei')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Propria pessoa')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Outro tipo de relacao')):
   df['vinculo_com_vitima'] = df['vinculo_com_vitima'] + ' ' + df[c].replace('Sim', c)

df['vinculo_com_vitima'] = [str(x).replace('Nao', '') for x in df['vinculo_com_vitima']]
df['vinculo_com_vitima'] = [' '.join(str(x).split()) for x in df['vinculo_com_vitima']]

# %%
def unique_list(l):
    ulist = []
    [ulist.append(x) for x in l if x not in ulist]
    return ulist

df['vinculo_com_vitima'] = [unique_list(str(x).split()) for x in df['vinculo_com_vitima']]
df['vinculo_com_vitima'] = [' '.join(list(x)) for x in df['vinculo_com_vitima']]

# %%
df.drop(columns=[
    'Pai',
    'Mãe',
    'Padrasto',
    'Madrasta',
    'Conjugue',
    'Ex-Conjunge',
    'Namorado(a)',
    'Ex-Namorado(a)',
    'Filho(a)',
    'Irmao(a)',
    'Conhecido(a)',
    'Desconhecido(a)',
    'Cuidador(a)',
    'Patrao(a)/Chefe(a)',
    'Relacao institucional',
    'Policial ou agente da lei',
    'Propria pessoa',
    'Outro tipo de relacao',
], axis=1, inplace=True)

# %%
df.head()
# Out:
#            ano_da_ocorrencia  anos_idade    sexo    raca estado_civil orientacao_sexual identidade_de_genero Possui deficiencia ou transtorno Deficiencia fisica Deficiencia mental Deficiencia visual Deficiencia auditiva Transtorno mental Transtorno comportamental Outras deficiencias ou transtornos estado_da_ocorrencia regiao_da_ocorrencia local_da_ocorrencia Lesão auto-provocada Motivo da violencia Violencia fisica Violencia psicológica Tortura Violencia sexual Trafico de seres humanos Violencia financeira ou economica Negligencia ou abandono Violencia infantil Violencia cometida por agente da lei Outros tipos de violência Forca corporal ou espancamento Enforcamento Objeto contundente Perfuro cortante Substancia ou objeto quente Envenenamento Arma de fogo Ameaca Outros tipos de agressao Assedio sexual    Estupro Pornografia infantil Exploracao sexual municipio_da_ocorrencia   latitude  longitude vinculo_com_vitima
# ID_AGRAVO
# ...

# %%
df[list(df.filter(like='Possui deficiencia ou transtorno'))] = df[list(df.filter(like='Possui deficiencia ou transtorno'))].fillna('Sem dados')
df[list(df.filter(like='Deficiencia'))] = df[list(df.filter(like='Deficiencia'))].fillna('Sem dados')
df[list(df.filter(like='Transtorno'))] = df[list(df.filter(like='Transtorno'))].fillna('Sem dados')
df[list(df.filter(like='Outras deficiencias ou transtornos'))] = df[list(df.filter(like='Outras deficiencias ou transtornos'))].fillna('Sem dados')

# %%
df['deficiencia_ou_transtorno'] = ""

for c in list(df.filter(like='Possui deficiencia ou transtorno')):
  df['deficiencia_ou_transtorno'] = df['deficiencia_ou_transtorno'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Deficiencia')):
   df['deficiencia_ou_transtorno'] = df['deficiencia_ou_transtorno'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Transtorno')):
   df['deficiencia_ou_transtorno'] = df['deficiencia_ou_transtorno'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Outras deficiencias ou transtornos')):
   df['deficiencia_ou_transtorno'] = df['deficiencia_ou_transtorno'] + ' ' + df[c].replace('Sim', c)

# %%
df['deficiencia_ou_transtorno'] = [str(x).replace('Nao', '') for x in df['deficiencia_ou_transtorno']]
df['deficiencia_ou_transtorno'] = [' '.join(str(x).split()) for x in df['deficiencia_ou_transtorno']]
df.head()
# Out:
#            ano_da_ocorrencia  anos_idade    sexo    raca estado_civil orientacao_sexual identidade_de_genero Possui deficiencia ou transtorno Deficiencia fisica Deficiencia mental Deficiencia visual Deficiencia auditiva Transtorno mental Transtorno comportamental Outras deficiencias ou transtornos estado_da_ocorrencia regiao_da_ocorrencia local_da_ocorrencia Lesão auto-provocada Motivo da violencia Violencia fisica Violencia psicológica Tortura Violencia sexual Trafico de seres humanos Violencia financeira ou economica Negligencia ou abandono Violencia infantil Violencia cometida por agente da lei Outros tipos de violência Forca corporal ou espancamento Enforcamento Objeto contundente Perfuro cortante Substancia ou objeto quente Envenenamento Arma de fogo Ameaca Outros tipos de agressao Assedio sexual    Estupro Pornografia infantil Exploracao sexual municipio_da_ocorrencia   latitude  longitude vinculo_com_vitima                                                        deficiencia_ou_
# ...

# %%
def unique_list(l):
    ulist = []
    [ulist.append(x) for x in l if x not in ulist]
    return ulist

df['deficiencia_ou_transtorno'] = [unique_list(str(x).split()) for x in df['deficiencia_ou_transtorno']]
df['deficiencia_ou_transtorno'] = [' '.join(list(x)) for x in df['deficiencia_ou_transtorno']]
df.head()
# Out:
#            ano_da_ocorrencia  anos_idade    sexo    raca estado_civil orientacao_sexual identidade_de_genero Possui deficiencia ou transtorno Deficiencia fisica Deficiencia mental Deficiencia visual Deficiencia auditiva Transtorno mental Transtorno comportamental Outras deficiencias ou transtornos estado_da_ocorrencia regiao_da_ocorrencia local_da_ocorrencia Lesão auto-provocada Motivo da violencia Violencia fisica Violencia psicológica Tortura Violencia sexual Trafico de seres humanos Violencia financeira ou economica Negligencia ou abandono Violencia infantil Violencia cometida por agente da lei Outros tipos de violência Forca corporal ou espancamento Enforcamento Objeto contundente Perfuro cortante Substancia ou objeto quente Envenenamento Arma de fogo Ameaca Outros tipos de agressao Assedio sexual    Estupro Pornografia infantil Exploracao sexual municipio_da_ocorrencia   latitude  longitude vinculo_com_vitima deficiencia_ou_transtorno
# ID_AGRAVO
# ...

# %%
df.drop(columns=[
  'Deficiencia fisica',
  'Deficiencia mental',
  'Deficiencia visual',
  'Deficiencia auditiva',
  'Transtorno mental',
  'Transtorno comportamental',
  'Outras deficiencias ou transtornos',
    ], axis=1, inplace=True)
df.head()
# Out:
#            ano_da_ocorrencia  anos_idade    sexo    raca estado_civil orientacao_sexual identidade_de_genero Possui deficiencia ou transtorno estado_da_ocorrencia regiao_da_ocorrencia local_da_ocorrencia Lesão auto-provocada Motivo da violencia Violencia fisica Violencia psicológica Tortura Violencia sexual Trafico de seres humanos Violencia financeira ou economica Negligencia ou abandono Violencia infantil Violencia cometida por agente da lei Outros tipos de violência Forca corporal ou espancamento Enforcamento Objeto contundente Perfuro cortante Substancia ou objeto quente Envenenamento Arma de fogo Ameaca Outros tipos de agressao Assedio sexual    Estupro Pornografia infantil Exploracao sexual municipio_da_ocorrencia   latitude  longitude vinculo_com_vitima deficiencia_ou_transtorno
# ID_AGRAVO
# ...

# %%
df[list(df.filter(like='Violencia'))] = df[list(df.filter(like='Violencia'))].fillna('Sem dados')
df[list(df.filter(like='Tortura'))] = df[list(df.filter(like='Tortura'))].fillna('Sem dados')
df[list(df.filter(like='Outros tipos de violência'))] = df[list(df.filter(like='Outros tipos de violência'))].fillna('Sem dados')
df[list(df.filter(like='Trafico de seres humanos'))] = df[list(df.filter(like='Trafico de seres humanos'))].fillna('Sem dados')
df[list(df.filter(like='Negligencia'))] = df[list(df.filter(like='Negligencia'))].fillna('Sem dados')

df['tipos_de_violencia'] = ""

for c in list(df.filter(like='Violencia')):
  df['tipos_de_violencia'] = df['tipos_de_violencia'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Tortura')):
   df['tipos_de_violencia'] = df['tipos_de_violencia'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Outros tipos de violência')):
   df['tipos_de_violencia'] = df['tipos_de_violencia'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Trafico de seres humanos')):
   df['tipos_de_violencia'] = df['tipos_de_violencia'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Negligencia')):
   df['tipos_de_violencia'] = df['tipos_de_violencia'] + ' ' + df[c].replace('Sim', c)

df['tipos_de_violencia'] = [str(x).replace('Nao', '') for x in df['tipos_de_violencia']]
df['tipos_de_violencia'] = [' '.join(str(x).split()) for x in df['tipos_de_violencia']]

def unique_list(l):
    ulist = []
    [ulist.append(x) for x in l if x not in ulist]
    return ulist

df['tipos_de_violencia'] = [unique_list(str(x).split()) for x in df['tipos_de_violencia']]
df['tipos_de_violencia'] = [' '.join(list(x)) for x in df['tipos_de_violencia']]


df.drop(columns=[
  'Motivo da violencia',
  'Violencia fisica',
  'Violencia psicológica',
  'Tortura',
  'Violencia sexual',
  'Trafico de seres humanos',
  'Violencia financeira ou economica',
  'Negligencia ou abandono',
  'Violencia infantil',
  'Violencia cometida por agente da lei',
  'Outros tipos de violência',
    ], axis=1, inplace=True)
df.head()
# Out:
#            ano_da_ocorrencia  anos_idade    sexo    raca estado_civil orientacao_sexual identidade_de_genero Possui deficiencia ou transtorno estado_da_ocorrencia regiao_da_ocorrencia local_da_ocorrencia Lesão auto-provocada Forca corporal ou espancamento Enforcamento Objeto contundente Perfuro cortante Substancia ou objeto quente Envenenamento Arma de fogo Ameaca Outros tipos de agressao Assedio sexual    Estupro Pornografia infantil Exploracao sexual municipio_da_ocorrencia   latitude  longitude vinculo_com_vitima deficiencia_ou_transtorno                   tipos_de_violencia
# ID_AGRAVO
# ...

# %%
df[list(df.filter(like='Lesão auto-provocada'))] = df[list(df.filter(like='Lesão auto-provocada'))].fillna('Sem dados')
df[list(df.filter(like='Forca corporal ou espancamento'))] = df[list(df.filter(like='Forca corporal ou espancamento'))].fillna('Sem dados')
df[list(df.filter(like='Enforcamento'))] = df[list(df.filter(like='Enforcamento'))].fillna('Sem dados')
df[list(df.filter(like='Objeto contundente'))] = df[list(df.filter(like='Objeto contundente'))].fillna('Sem dados')
df[list(df.filter(like='Perfuro cortante'))] = df[list(df.filter(like='Perfuro cortante'))].fillna('Sem dados')
df[list(df.filter(like='Substancia ou objeto quente'))] = df[list(df.filter(like='Substancia ou objeto quente'))].fillna('Sem dados')
df[list(df.filter(like='Envenenamento'))] = df[list(df.filter(like='Envenenamento'))].fillna('Sem dados')
df[list(df.filter(like='Arma de fogo'))] = df[list(df.filter(like='Arma de fogo'))].fillna('Sem dados')
df[list(df.filter(like='Ameaca'))] = df[list(df.filter(like='Ameaca'))].fillna('Sem dados')
df[list(df.filter(like='Outros tipos de agressao'))] = df[list(df.filter(like='Outros tipos de agressao'))].fillna('Sem dados')
df[list(df.filter(like='Assedio sexual'))] = df[list(df.filter(like='Assedio sexual'))].fillna('Sem dados')
df[list(df.filter(like='Estupro'))] = df[list(df.filter(like='Estupro'))].fillna('Sem dados')
df[list(df.filter(like='Pornografia infantil'))] = df[list(df.filter(like='Pornografia infantil'))].fillna('Sem dados')
df[list(df.filter(like='Exploracao sexual'))] = df[list(df.filter(like='Exploracao sexual'))].fillna('Sem dados')

df['meio_da_agressao'] = ""

for c in list(df.filter(like='Lesão auto-provocada')):
  df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Forca corporal ou espancamento')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Enforcamento')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Objeto contundente')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Perfuro cortante')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Substancia ou objeto quente')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Envenenamento')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Ameaca')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Outros tipos de agressao')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Assedio sexual')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Estupro')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Pornografia infantil')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)

for c in list(df.filter(like='Exploracao sexual')):
   df['meio_da_agressao'] = df['meio_da_agressao'] + ' ' + df[c].replace('Sim', c)


df['meio_da_agressao'] = [str(x).replace('Nao', '') for x in df['meio_da_agressao']]
df['meio_da_agressao'] = [' '.join(str(x).split()) for x in df['meio_da_agressao']]

def unique_list(l):
    ulist = []
    [ulist.append(x) for x in l if x not in ulist]
    return ulist

df['meio_da_agressao'] = [unique_list(str(x).split()) for x in df['meio_da_agressao']]
df['meio_da_agressao'] = [' '.join(list(x)) for x in df['meio_da_agressao']]


df.drop(columns=[
    'Lesão auto-provocada',
    'Forca corporal ou espancamento',
    'Enforcamento',
    'Objeto contundente',
    'Perfuro cortante',
    'Substancia ou objeto quente',
    'Envenenamento',
    'Arma de fogo',
    'Ameaca',
    'Outros tipos de agressao',
    'Assedio sexual',
    'Estupro',
    'Pornografia infantil',
    'Exploracao sexual',
    'Possui deficiencia ou transtorno',
    ], axis=1, inplace=True)
df.head()
# Out:
#            ano_da_ocorrencia  anos_idade    sexo    raca estado_civil orientacao_sexual identidade_de_genero estado_da_ocorrencia regiao_da_ocorrencia local_da_ocorrencia municipio_da_ocorrencia   latitude  longitude vinculo_com_vitima deficiencia_ou_transtorno                   tipos_de_violencia                                                                      meio_da_agressao
# ID_AGRAVO
# Y09        2017.0             40.0        Mulher  Branca  Solteiro     Heterossexual     Sem dados            SP                   SUDESTE              Sem dados           SAO PAULO              -46.647416 -23.649307  Propria pessoa     Sem dados                 Violencia fisica psicológica         Lesão auto-provocada Outros tipos de agressao Sem dados
# ...

# %%
df['ano_da_ocorrencia'] = df['ano_da_ocorrencia'].astype('int')
df['anos_idade'] = df['anos_idade'].astype('int')
df['sexo'] = df['sexo'].astype('str')
df['raca'] = df['raca'].astype('str')
df['estado_civil'] = df['estado_civil'].astype('str')
df['orientacao_sexual'] = df['orientacao_sexual'].astype('str')
df['identidade_de_genero'] = df['identidade_de_genero'].astype('str')
df['deficiencia_ou_transtorno'] = df['deficiencia_ou_transtorno'].astype('str')
df['vinculo_com_vitima'] = df['vinculo_com_vitima'].astype('str')
df['tipos_de_violencia'] = df['tipos_de_violencia'].astype('str')
df['meio_da_agressao'] = df['meio_da_agressao'].astype('str')
df['local_da_ocorrencia'] = df['local_da_ocorrencia'].astype('str')
df['meio_da_agressao'] = df['meio_da_agressao'].astype('str')
df['estado_da_ocorrencia'] = df['estado_da_ocorrencia'].astype('str')
df['regiao_da_ocorrencia'] = df['regiao_da_ocorrencia'].astype('str')
df['municipio_da_ocorrencia'] = df['municipio_da_ocorrencia'].astype('str')

df.dtypes
# Out:
# ano_da_ocorrencia            int64
# anos_idade                   int64
# sexo                         object
# raca                         object
# estado_civil                 object
# orientacao_sexual            object
# identidade_de_genero         object
# estado_da_ocorrencia         object
# regiao_da_ocorrencia         object
# local_da_ocorrencia          object
# municipio_da_ocorrencia      object
# latitude                     float64
# longitude                    float64
# vinculo_com_vitima           object
# deficiencia_ou_transtorno    object
# tipos_de_violencia           object
# meio_da_agressao             object
# dtype: object

# %%
df['base_dados'] = 'SINAN'

# %%
df.rename({
    'latitude': 'longitude',
    'longitude': 'latitude',
}, axis=1, inplace=True)



# meio_de_agressao
# tipo_de_agressao
# vinculo_com_vitima,
# base_dados

# %%
df.to_csv('crime_reports_SINAN_novo.csv')

# %%
df.head()
# Out:
#            ano_da_ocorrencia  anos_idade    sexo    raca estado_civil orientacao_sexual identidade_de_genero estado_da_ocorrencia regiao_da_ocorrencia local_da_ocorrencia municipio_da_ocorrencia   latitude  longitude vinculo_com_vitima deficiencia_ou_transtorno                   tipos_de_violencia                                                                      meio_da_agressao base_dados
# ID_AGRAVO
# Y09        2017               40          Mulher  Branca  Solteiro     Heterossexual     Sem dados            SP                   SUDESTE              Sem dados           SAO PAULO              -46.647416 -23.649307  Propria pessoa     Sem dados                 Violencia fisica psicológica         Lesão auto-provocada Outros tipos de agressao Sem dados                               SINAN
# ...
